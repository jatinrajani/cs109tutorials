# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#creating series
s=pd.Series([1,3,5,np.nan,7,9])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    7.0
# 5    9.0
# dtype: float64

# %%
dates=pd.date_range('20180505',periods=7)

# %%
dates
# Out:
# DatetimeIndex(['2018-05-05', '2018-05-06', '2018-05-07', '2018-05-08',
#                '2018-05-09', '2018-05-10', '2018-05-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.randn?

# %%
df=pd.DataFrame(np.random.randn(7,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2018-05-05  1.901041  1.327726 -0.325097  1.428891
# 2018-05-06  0.845827  0.193673  1.285295 -1.006213
# 2018-05-07 -0.626925 -0.072908 -1.213082 -2.318644
# 2018-05-08  0.541525  1.166605 -0.937115  0.368397
# 2018-05-09 -0.340859  0.548135 -1.208557  0.105368
# 2018-05-10 -0.660560 -0.103533 -0.119031 -1.243886
# 2018-05-11 -0.250225  0.826718  0.353479 -0.554912

# %%
df2=pd.DataFrame({'A':1,
                 'B':pd.date_range('20140102',periods=5),
                 'C':pd.Categorical(["test","hi","bye","jatin","karan"])})

# %%
df2
# Out:
#    A          B      C
# 0  1 2014-01-02   test
# 1  1 2014-01-03     hi
# 2  1 2014-01-04    bye
# 3  1 2014-01-05  jatin
# 4  1 2014-01-06  karan

# %%
df2.describe()
# Out:
#          A
# count  5.0
# mean   1.0
# std    0.0
# min    1.0
# 25%    1.0
# 50%    1.0
# 75%    1.0
# max    1.0

# %%
df2.boxplot()

# %%
df.head()
# Out:
#                    A         B         C         D
# 2018-05-05  1.901041  1.327726 -0.325097  1.428891
# 2018-05-06  0.845827  0.193673  1.285295 -1.006213
# 2018-05-07 -0.626925 -0.072908 -1.213082 -2.318644
# 2018-05-08  0.541525  1.166605 -0.937115  0.368397
# 2018-05-09 -0.340859  0.548135 -1.208557  0.105368

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2018-05-09 -0.340859  0.548135 -1.208557  0.105368
# 2018-05-10 -0.660560 -0.103533 -0.119031 -1.243886
# 2018-05-11 -0.250225  0.826718  0.353479 -0.554912

# %%
df.index
# Out:
# DatetimeIndex(['2018-05-05', '2018-05-06', '2018-05-07', '2018-05-08',
#                '2018-05-09', '2018-05-10', '2018-05-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
df
# Out:
#                    A         B         C         D
# 2018-05-05  1.901041  1.327726 -0.325097  1.428891
# 2018-05-06  0.845827  0.193673  1.285295 -1.006213
# 2018-05-07 -0.626925 -0.072908 -1.213082 -2.318644
# 2018-05-08  0.541525  1.166605 -0.937115  0.368397
# 2018-05-09 -0.340859  0.548135 -1.208557  0.105368
# 2018-05-10 -0.660560 -0.103533 -0.119031 -1.243886
# 2018-05-11 -0.250225  0.826718  0.353479 -0.554912

# %%
df.T
# Out:
#    2018-05-05  2018-05-06  2018-05-07  2018-05-08  2018-05-09  2018-05-10  \
# A    1.901041    0.845827   -0.626925    0.541525   -0.340859   -0.660560
# B    1.327726    0.193673   -0.072908    1.166605    0.548135   -0.103533
# C   -0.325097    1.285295   -1.213082   -0.937115   -1.208557   -0.119031
# D    1.428891   -1.006213   -2.318644    0.368397    0.105368   -1.243886
#
#    2018-05-11
# A   -0.250225
# B    0.826718
# C    0.353479
# D   -0.554912

# %%
df
# Out:
#                    A         B         C         D
# 2018-05-05  1.901041  1.327726 -0.325097  1.428891
# 2018-05-06  0.845827  0.193673  1.285295 -1.006213
# 2018-05-07 -0.626925 -0.072908 -1.213082 -2.318644
# 2018-05-08  0.541525  1.166605 -0.937115  0.368397
# 2018-05-09 -0.340859  0.548135 -1.208557  0.105368
# 2018-05-10 -0.660560 -0.103533 -0.119031 -1.243886
# 2018-05-11 -0.250225  0.826718  0.353479 -0.554912

# %%
df.sort_values(by='B',ascending=False)
# Out:
#                    A         B         C         D
# 2018-05-05  1.901041  1.327726 -0.325097  1.428891
# 2018-05-08  0.541525  1.166605 -0.937115  0.368397
# 2018-05-11 -0.250225  0.826718  0.353479 -0.554912
# 2018-05-09 -0.340859  0.548135 -1.208557  0.105368
# 2018-05-06  0.845827  0.193673  1.285295 -1.006213
# 2018-05-07 -0.626925 -0.072908 -1.213082 -2.318644
# 2018-05-10 -0.660560 -0.103533 -0.119031 -1.243886

# %%
df['A']
# Out:
# 2018-05-05    1.901041
# 2018-05-06    0.845827
# 2018-05-07   -0.626925
# 2018-05-08    0.541525
# 2018-05-09   -0.340859
# 2018-05-10   -0.660560
# 2018-05-11   -0.250225
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2018-05-05  1.901041  1.327726 -0.325097  1.428891
# 2018-05-06  0.845827  0.193673  1.285295 -1.006213
# 2018-05-07 -0.626925 -0.072908 -1.213082 -2.318644

# %%
#selection by label
df.loc[dates[1]]
# Out:
# A    0.845827
# B    0.193673
# C    1.285295
# D   -1.006213
# Name: 2018-05-06 00:00:00, dtype: float64

# %%
#selection by multi axis label
df.loc[dates[0],['A','B']]
# Out:
# A    1.901041
# B    1.327726
# Name: 2018-05-05 00:00:00, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2018-05-05  1.901041  1.327726 -0.325097  1.428891
# 2018-05-06  0.845827  0.193673  1.285295 -1.006213
# 2018-05-07 -0.626925 -0.072908 -1.213082 -2.318644
# 2018-05-08  0.541525  1.166605 -0.937115  0.368397
# 2018-05-09 -0.340859  0.548135 -1.208557  0.105368
# 2018-05-10 -0.660560 -0.103533 -0.119031 -1.243886
# 2018-05-11 -0.250225  0.826718  0.353479 -0.554912

# %%
df.at[dates[0],'A']
# Out:
# 1.901041273471231

# %%
#selection by poosition
df.iloc[3]
# Out:
# A    0.541525
# B    1.166605
# C   -0.937115
# D    0.368397
# Name: 2018-05-08 00:00:00, dtype: float64

# %%
df.loc[:,['A','B','C']]
# Out:
#                    A         B         C
# 2018-05-05  1.901041  1.327726 -0.325097
# 2018-05-06  0.845827  0.193673  1.285295
# 2018-05-07 -0.626925 -0.072908 -1.213082
# 2018-05-08  0.541525  1.166605 -0.937115
# 2018-05-09 -0.340859  0.548135 -1.208557
# 2018-05-10 -0.660560 -0.103533 -0.119031
# 2018-05-11 -0.250225  0.826718  0.353479

# %%
df.iloc[:,0:3]
# Out:
#                    A         B         C
# 2018-05-05  1.901041  1.327726 -0.325097
# 2018-05-06  0.845827  0.193673  1.285295
# 2018-05-07 -0.626925 -0.072908 -1.213082
# 2018-05-08  0.541525  1.166605 -0.937115
# 2018-05-09 -0.340859  0.548135 -1.208557
# 2018-05-10 -0.660560 -0.103533 -0.119031
# 2018-05-11 -0.250225  0.826718  0.353479

# %%
df.loc[dates[1],'B']
# Out:
# 0.19367269902153694

# %%
df.iloc[1,1]
# Out:
# 0.19367269902153694

# %%
#boolean indexing
df[df.A>0]
# Out:
#                    A         B         C         D
# 2018-05-05  1.901041  1.327726 -0.325097  1.428891
# 2018-05-06  0.845827  0.193673  1.285295 -1.006213
# 2018-05-08  0.541525  1.166605 -0.937115  0.368397

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2018-05-05  1.901041  1.327726       NaN  1.428891
# 2018-05-06  0.845827  0.193673  1.285295       NaN
# 2018-05-07       NaN       NaN       NaN       NaN
# 2018-05-08  0.541525  1.166605       NaN  0.368397
# 2018-05-09       NaN  0.548135       NaN  0.105368
# 2018-05-10       NaN       NaN       NaN       NaN
# 2018-05-11       NaN  0.826718  0.353479       NaN

# %%
df3=df.copy()

# %%
df3
# Out:
# <bound method DataFrame.copy of                    A         B         C         D
# 2018-05-05  1.901041  1.327726 -0.325097  1.428891
# 2018-05-06  0.845827  0.193673  1.285295 -1.006213
# 2018-05-07 -0.626925 -0.072908 -1.213082 -2.318644
# 2018-05-08  0.541525  1.166605 -0.937115  0.368397
# 2018-05-09 -0.340859  0.548135 -1.208557  0.105368
# 2018-05-10 -0.660560 -0.103533 -0.119031 -1.243886
# 2018-05-11 -0.250225  0.826718  0.353479 -0.554912>

# %%
df3['A']=['one','two','three','four','five','six','seven']

# %%
df3
# Out:
#                 A         B         C         D
# 2018-05-05    one  1.327726 -0.325097  1.428891
# 2018-05-06    two  0.193673  1.285295 -1.006213
# 2018-05-07  three -0.072908 -1.213082 -2.318644
# 2018-05-08   four  1.166605 -0.937115  0.368397
# 2018-05-09   five  0.548135 -1.208557  0.105368
# 2018-05-10    six -0.103533 -0.119031 -1.243886
# 2018-05-11  seven  0.826718  0.353479 -0.554912

# %%
df3[df3['A'].isin(['one','five'])]
# Out:
#                A         B         C         D
# 2018-05-05   one  1.327726 -0.325097  1.428891
# 2018-05-09  five  0.548135 -1.208557  0.105368

# %%
df.loc[dates[3],:]
# Out:
# A    0.541525
# B    1.166605
# C   -0.937115
# D    0.368397
# Name: 2018-05-08 00:00:00, dtype: float64

# %%
#setting
s1=pd.Series([1,2,3,4,5,7,8],index=pd.date_range('20100102',periods=7))

# %%
df['E']=s1

# %%
s1 = pd.Series([1,2,3,4,5,6,7], index=pd.date_range('20130102', periods=7))

# %%
df['E']=s1

# %%
df.at[dates[0],'A']=0

# %%
df.iat[0,1]=0

# %%
df.loc[:,'D']=np.array([1]*len(df))

# %%
df
# Out:
#                    A         B         C  D   E
# 2018-05-05  0.000000  0.000000 -0.325097  1 NaN
# 2018-05-06  0.845827  0.193673  1.285295  1 NaN
# 2018-05-07 -0.626925 -0.072908 -1.213082  1 NaN
# 2018-05-08  0.541525  1.166605 -0.937115  1 NaN
# 2018-05-09 -0.340859  0.548135 -1.208557  1 NaN
# 2018-05-10 -0.660560 -0.103533 -0.119031  1 NaN
# 2018-05-11 -0.250225  0.826718  0.353479  1 NaN

# %%
df1=df.copy()

# %%
df1
# Out:
#                    A         B         C  D   E
# 2018-05-05  0.000000  0.000000 -0.325097  1 NaN
# 2018-05-06  0.845827  0.193673  1.285295  1 NaN
# 2018-05-07 -0.626925 -0.072908 -1.213082  1 NaN
# 2018-05-08  0.541525  1.166605 -0.937115  1 NaN
# 2018-05-09 -0.340859  0.548135 -1.208557  1 NaN
# 2018-05-10 -0.660560 -0.103533 -0.119031  1 NaN
# 2018-05-11 -0.250225  0.826718  0.353479  1 NaN

# %%
df1.iloc[0:2,4]=1

# %%
df1
# Out:
#                    A         B         C  D    E
# 2018-05-05  0.000000  0.000000 -0.325097  1  1.0
# 2018-05-06  0.845827  0.193673  1.285295  1  1.0
# 2018-05-07 -0.626925 -0.072908 -1.213082  1  NaN
# 2018-05-08  0.541525  1.166605 -0.937115  1  NaN
# 2018-05-09 -0.340859  0.548135 -1.208557  1  NaN
# 2018-05-10 -0.660560 -0.103533 -0.119031  1  NaN
# 2018-05-11 -0.250225  0.826718  0.353479  1  NaN

# %%
#any is used for rows that have missing data
df1.dropna(how='any')
# Out:
#                    A         B         C  D    E
# 2018-05-05  0.000000  0.000000 -0.325097  1  1.0
# 2018-05-06  0.845827  0.193673  1.285295  1  1.0

# %%
#for filling na value
df1.fillna(value=0)
# Out:
#                    A         B         C  D    E
# 2018-05-05  0.000000  0.000000 -0.325097  1  1.0
# 2018-05-06  0.845827  0.193673  1.285295  1  1.0
# 2018-05-07 -0.626925 -0.072908 -1.213082  1  0.0
# 2018-05-08  0.541525  1.166605 -0.937115  1  0.0
# 2018-05-09 -0.340859  0.548135 -1.208557  1  0.0
# 2018-05-10 -0.660560 -0.103533 -0.119031  1  0.0
# 2018-05-11 -0.250225  0.826718  0.353479  1  0.0

# %%
#to get rows where values are nan
df1.isna()
# Out:
#                 A      B      C      D      E
# 2018-05-05  False  False  False  False  False
# 2018-05-06  False  False  False  False  False
# 2018-05-07  False  False  False  False   True
# 2018-05-08  False  False  False  False   True
# 2018-05-09  False  False  False  False   True
# 2018-05-10  False  False  False  False   True
# 2018-05-11  False  False  False  False   True

# %%
#operations

# %%
df.mean()
# Out:
# A   -0.070174
# B    0.365527
# C   -0.309158
# D    1.000000
# E         NaN
# dtype: float64

# %%
df=df.fillna(value=1)

# %%
df.mean(1)
# Out:
# 2018-05-05    0.334981
# 2018-05-06    0.864959
# 2018-05-07    0.017417
# 2018-05-08    0.554203
# 2018-05-09    0.199744
# 2018-05-10    0.223375
# 2018-05-11    0.585994
# Freq: D, dtype: float64

# %%
s=pd.Series([1,3,5,np.nan,7,8,7],index=dates
            )

# %%
len(dates)
# Out:
# 7

# %%
s
# Out:
# 2018-05-05    1.0
# 2018-05-06    3.0
# 2018-05-07    5.0
# 2018-05-08    NaN
# 2018-05-09    7.0
# 2018-05-10    8.0
# 2018-05-11    7.0
# Freq: D, dtype: float64

# %%
s.shift(5)
# Out:
# 2018-05-05    NaN
# 2018-05-06    NaN
# 2018-05-07    NaN
# 2018-05-08    NaN
# 2018-05-09    NaN
# 2018-05-10    1.0
# 2018-05-11    3.0
# Freq: D, dtype: float64

# %%
df.sub(s,axis="index")
# Out:
#                    A         B         C    D    E
# 2018-05-05 -1.000000 -1.000000 -1.325097  0.0  0.0
# 2018-05-06 -2.154173 -2.806327 -1.714705 -2.0 -2.0
# 2018-05-07 -5.626925 -5.072908 -6.213082 -4.0 -4.0
# 2018-05-08       NaN       NaN       NaN  NaN  NaN
# 2018-05-09 -7.340859 -6.451865 -8.208557 -6.0 -6.0
# 2018-05-10 -8.660560 -8.103533 -8.119031 -7.0 -7.0
# 2018-05-11 -7.250225 -6.173282 -6.646521 -6.0 -6.0

# %%
df
# Out:
#                    A         B         C  D    E
# 2018-05-05  0.000000  0.000000 -0.325097  1  1.0
# 2018-05-06  0.845827  0.193673  1.285295  1  1.0
# 2018-05-07 -0.626925 -0.072908 -1.213082  1  1.0
# 2018-05-08  0.541525  1.166605 -0.937115  1  1.0
# 2018-05-09 -0.340859  0.548135 -1.208557  1  1.0
# 2018-05-10 -0.660560 -0.103533 -0.119031  1  1.0
# 2018-05-11 -0.250225  0.826718  0.353479  1  1.0

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C  D    E
# 2018-05-05  0.000000  0.000000 -0.325097  1  1.0
# 2018-05-06  0.845827  0.193673  0.960198  2  2.0
# 2018-05-07  0.218902  0.120764 -0.252884  3  3.0
# 2018-05-08  0.760428  1.287369 -1.189999  4  4.0
# 2018-05-09  0.419568  1.835504 -2.398556  5  5.0
# 2018-05-10 -0.240991  1.731970 -2.517587  6  6.0
# 2018-05-11 -0.491216  2.558689 -2.164108  7  7.0

# %%
a.cumsum
# Out:
# <function cumsum>

# %%
df.apply(lambda x:x.max()-x.min())
# Out:
# A    1.506387
# B    1.270138
# C    2.498377
# D    0.000000
# E    0.000000
# dtype: float64

# %%
a
# Out:
# array([0, 1])

# %%
a.cumsum()
# Out:
# array([0, 1])

# %%
a.cumsum
# Out:
# <function cumsum>

# %%
np.cumsum(a)
# Out:
# array([0, 1])

# %%
s2=pd.Series(np.random.randint(0,7,size=5))

# %%
s2
# Out:
# 0    3
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
s2.value_counts()
# Out:
# 3    2
# 6    1
# 5    1
# 4    1
# dtype: int64

# %%
#string methods
s=pd.Series(["hi","jatin","lets","MEEET","TOMMORROW"])

# %%
s.value_counts()
# Out:
# jatin        1
# hi           1
# lets         1
# TOMMORROW    1
# MEEET        1
# dtype: int64

# %%
s.str.lower()
# Out:
# 0           hi
# 1        jatin
# 2         lets
# 3        meeet
# 4    tommorrow
# dtype: object

# %%
#Concatenation
df=pd.DataFrame(np.random.randn(7,4))

# %%
pieces=[df[:3],df[3:7],df[7:]]

# %%
pieces
# Out:
# [          0         1         2         3
#  0  0.541105 -0.575340 -0.445285  1.306169
#  1 -0.391421 -1.133262 -0.209960 -0.052428
#  2  1.251553  0.361887  1.359980  0.848598,
#            0         1         2         3
#  3 -1.094070  0.698398  1.254874  0.031237
#  4 -0.322400 -0.204037  0.481264 -0.435267
#  5 -0.980604 -0.520479 -0.234330 -1.182390
#  6  0.340701 -0.355412  0.056016 -1.398571,
#  Empty DataFrame
#  Columns: [0, 1, 2, 3]
#  Index: []]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.541105 -0.575340 -0.445285  1.306169
# 1 -0.391421 -1.133262 -0.209960 -0.052428
# 2  1.251553  0.361887  1.359980  0.848598
# 3 -1.094070  0.698398  1.254874  0.031237
# 4 -0.322400 -0.204037  0.481264 -0.435267
# 5 -0.980604 -0.520479 -0.234330 -1.182390
# 6  0.340701 -0.355412  0.056016 -1.398571

# %%
c=pd.DataFrame(np.random.randn(3,4))

# %%
c
# Out:
#           0         1         2         3
# 0 -0.959680 -1.339063  0.184935 -1.133171
# 1 -0.935444  1.320894  0.507565 -0.916404
# 2 -1.356323 -0.066535 -0.444356  1.104044

# %%
pieces=[df,c]

# %%
pd.concat(pieces,ignore_index=True)
# Out:
#           0         1         2         3
# 0  0.541105 -0.575340 -0.445285  1.306169
# 1 -0.391421 -1.133262 -0.209960 -0.052428
# 2  1.251553  0.361887  1.359980  0.848598
# 3 -1.094070  0.698398  1.254874  0.031237
# 4 -0.322400 -0.204037  0.481264 -0.435267
# 5 -0.980604 -0.520479 -0.234330 -1.182390
# 6  0.340701 -0.355412  0.056016 -1.398571
# 7 -0.959680 -1.339063  0.184935 -1.133171
# 8 -0.935444  1.320894  0.507565 -0.916404
# 9 -1.356323 -0.066535 -0.444356  1.104044

# %%
left=pd.DataFrame({'key':['foof','foo'],'lval':[1,4]})

# %%
left
# Out:
#     key  lval
# 0  foof     1
# 1   foo     4

# %%
right=pd.DataFrame({'key':['foof','foo'],'rval':[3,5]})

# %%
right
# Out:
#     key  rval
# 0  baar     1
# 1   bar     5

# %%
a=[left,right]

# %%
#merge
pd.merge(left,right,on='key')
# Out:
#     key  lval  rval
# 0  foof     1     3
# 1   foo     4     5

# %%
df.iloc[3]
# Out:
# 0   -1.094070
# 1    0.698398
# 2    1.254874
# 3    0.031237
# Name: 3, dtype: float64

# %%
df
# Out:
#           0         1         2         3
# 0  0.541105 -0.575340 -0.445285  1.306169
# 1 -0.391421 -1.133262 -0.209960 -0.052428
# 2  1.251553  0.361887  1.359980  0.848598
# 3 -1.094070  0.698398  1.254874  0.031237
# 4 -0.322400 -0.204037  0.481264 -0.435267
# 5 -0.980604 -0.520479 -0.234330 -1.182390
# 6  0.340701 -0.355412  0.056016 -1.398571

# %%
df.columns=['A','B','C','D']

# %%
df
# Out:
#           A         B         C         D
# 0  0.541105 -0.575340 -0.445285  1.306169
# 1 -0.391421 -1.133262 -0.209960 -0.052428
# 2  1.251553  0.361887  1.359980  0.848598
# 3 -1.094070  0.698398  1.254874  0.031237
# 4 -0.322400 -0.204037  0.481264 -0.435267
# 5 -0.980604 -0.520479 -0.234330 -1.182390
# 6  0.340701 -0.355412  0.056016 -1.398571

# %%
df.rows=['boo','far','fat','thin','hi','bye','jk']

# %%
df.groupby(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-215-92c9a0d425a1> in <module>()
# ----> 1 df.groupby(0)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# -> 1848     return klass(obj, by, **kwds)
#    1849
#    1850
#
# ...

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ....:                           'foo', 'bar', 'foo', 'foo'],
   ....:                    'B' : ['one', 'one', 'two', 'three',
   ....:                           'two', 'two', 'one', 'three'],
   ....:                    'C' : np.random.randn(8),
   ....:                    'D' : np.random.randn(8)})

# %%
dfdf = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ....:                           'foo', 'bar', 'foo', 'foo'],
   ....:                    'B' : ['one', 'one', 'two', 'three',
   ....:                           'two', 'two', 'one', 'three'],
   ....:                    'C' : np.random.randn(8),
   ....:                    'D' : np.random.randn(8)})
# Out:
#      A      B         C         D
# 0  foo    one  2.112462 -1.119466
# 1  bar    one  0.546589  1.116270
# 2  foo    two -3.251599  1.187943
# 3  bar  three -0.723408 -0.510284
# 4  foo    two  0.203537  0.237056
# 5  bar    two -0.647660 -1.326902
# 6  foo    one  2.962087  1.147389
# 7  foo  three -0.777200  0.943289

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.546589  1.116270
#     three -0.723408 -0.510284
#     two   -0.647660 -1.326902
# foo one    5.074550  0.027923
#     three -0.777200  0.943289
#     two   -3.048061  1.424999

# %%
#writing to excel

# %%
import openpyxl
df.to_excel('foo.xlsx',sheet_name='Sheet1')

# %%
import xlrd

pd.read_excel('foo.xlsx','Sheet1',index_col=None,na_value=['NA'])
# Out:
#      A      B         C         D
# 0  foo    one  2.112462 -1.119466
# 1  bar    one  0.546589  1.116270
# 2  foo    two -3.251599  1.187943
# 3  bar  three -0.723408 -0.510284
# 4  foo    two  0.203537  0.237056
# 5  bar    two -0.647660 -1.326902
# 6  foo    one  2.962087  1.147389
# 7  foo  three -0.777200  0.943289

# %%
df.to_hdf('foo.h5','df')

# %%
pd.read_hdf('foo.h5','df')
# Out:
#      A      B         C         D
# 0  foo    one  2.112462 -1.119466
# 1  bar    one  0.546589  1.116270
# 2  foo    two -3.251599  1.187943
# 3  bar  three -0.723408 -0.510284
# 4  foo    two  0.203537  0.237056
# 5  bar    two -0.647660 -1.326902
# 6  foo    one  2.962087  1.147389
# 7  foo  three -0.777200  0.943289

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv',index_col=None)
# Out:
#    Unnamed: 0    A      B         C         D
# 0           0  foo    one  2.112462 -1.119466
# 1           1  bar    one  0.546589  1.116270
# 2           2  foo    two -3.251599  1.187943
# 3           3  bar  three -0.723408 -0.510284
# 4           4  foo    two  0.203537  0.237056
# 5           5  bar    two -0.647660 -1.326902
# 6           6  foo    one  2.962087  1.147389
# 7           7  foo  three -0.777200  0.943289

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range('20130101',periods=1000))

# %%
ts=ts=ts.cumsum()

# %%
import seaborn as sns

# %%
sns.distplot(ts)

# %%
ts[0]
# Out:
# 0.11591230208704119

# %%
a=ts.iloc[:]

# %%
dates=ts.iloc[:,]

# %%
dates[0:len(dates)]
# Out:
# 2013-01-01     0.115912
# 2013-01-02     0.605802
# 2013-01-03     0.303180
# 2013-01-04     0.572669
# 2013-01-05     1.284966
# 2013-01-06     0.670650
# 2013-01-07     0.933318
# 2013-01-08    -0.060912
# 2013-01-09     0.767052
# 2013-01-10     0.063590
# 2013-01-11     0.430700
# 2013-01-12     1.323312
# 2013-01-13     3.310285
# 2013-01-14     3.708447
# 2013-01-15     1.970498
# 2013-01-16     3.373555
# 2013-01-17     3.289282
# 2013-01-18     2.137344
# 2013-01-19     2.404285
# 2013-01-20     1.611938
# 2013-01-21     2.904724
# 2013-01-22     2.389129
# 2013-01-23     2.606190
# 2013-01-24     2.551138
# 2013-01-25     2.076094
# 2013-01-26     0.603943
# 2013-01-27    -0.201936
# 2013-01-28     0.298487
# 2013-01-29    -0.342999
# 2013-01-30    -2.035867
#                 ...
# 2015-08-29   -26.801840
# 2015-08-30   -26.097283
# 2015-08-31   -26.619613
# 2015-09-01   -27.353845
# 2015-09-02   -27.270449
# 2015-09-03   -28.389905
# 2015-09-04   -27.813524
# ...

# %%
df.iloc[,[1]]
# Out:
#   File "<ipython-input-273-a56356f02150>", line 1
#     df.iloc[,[1]]
#             ^
# SyntaxError: invalid syntax

# %%
ts.plot()

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  2.112462 -1.119466
# 1  bar    one  0.546589  1.116270
# 2  foo    two -3.251599  1.187943
# 3  bar  three -0.723408 -0.510284
# 4  foo    two  0.203537  0.237056
# 5  bar    two -0.647660 -1.326902
# 6  foo    one  2.962087  1.147389
# 7  foo  three -0.777200  0.943289

# %%
df=pd.DataFrame(np.random.randn(1000,4),index=ts.index,columns=['A','B','C','D'])

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.972344 -1.030019  0.352367 -0.259548
# 2013-01-02  0.124141  0.457880  0.985866 -0.321683
# 2013-01-03  0.137055  1.096318 -0.241474 -0.570129
# 2013-01-04  0.066139  0.404603  0.317951 -1.213304
# 2013-01-05 -0.876526  0.920753 -0.569368 -0.846395
# 2013-01-06  0.952496 -2.342077  0.020716 -0.505358
# 2013-01-07  0.380284  0.871924 -0.021672 -0.551526
# 2013-01-08  0.303494  0.993058 -0.846886  2.170568
# 2013-01-09  1.071015 -0.067844 -0.549978  1.100372
# 2013-01-10  0.678742  0.561133 -0.018873 -1.189562
# 2013-01-11 -0.246493 -0.155955 -0.062219  0.174253
# 2013-01-12  0.147687 -0.390378  1.971546 -0.150080
# 2013-01-13 -0.251658  0.306535  0.983232 -0.072531
# 2013-01-14  0.142550  0.351052 -0.722196 -0.743171
# 2013-01-15  0.037375 -1.286678 -1.095056  0.157102
# 2013-01-16  0.062102  1.129809  0.328562 -0.528119
# 2013-01-17 -0.287011 -1.129428 -1.552626  1.623123
# ...

# %%
df=df.cumsum()
df
# Out:
#                     A          B          C          D
# 2013-01-01  -0.972344  -1.030019   0.352367  -0.259548
# 2013-01-02  -0.848203  -0.572139   1.338233  -0.581232
# 2013-01-03  -0.711148   0.524179   1.096759  -1.151360
# 2013-01-04  -0.645009   0.928781   1.414710  -2.364664
# 2013-01-05  -1.521534   1.849534   0.845342  -3.211059
# 2013-01-06  -0.569039  -0.492543   0.866058  -3.716416
# 2013-01-07  -0.188755   0.379382   0.844386  -4.267943
# 2013-01-08   0.114739   1.372440  -0.002500  -2.097374
# 2013-01-09   1.185754   1.304595  -0.552478  -0.997003
# 2013-01-10   1.864497   1.865729  -0.571350  -2.186565
# 2013-01-11   1.618003   1.709774  -0.633570  -2.012313
# 2013-01-12   1.765691   1.319396   1.337977  -2.162393
# 2013-01-13   1.514033   1.625931   2.321209  -2.234924
# 2013-01-14   1.656583   1.976983   1.599013  -2.978095
# 2013-01-15   1.693958   0.690305   0.503957  -2.820993
# 2013-01-16   1.756060   1.820114   0.832520  -3.349112
# ...

# %%
plt.figure();df.plot();plt.legend(loc='best')

# %%
dfgrades=pd.DataFrame({'id':[0,1,2,3,4,5,7,8],'grade':['a','b','c','a','b','c','a','b']})

# %%
dfgrades
# Out:
#   grade  id
# 0     a   0
# 1     b   1
# 2     c   2
# 3     a   3
# 4     b   4
# 5     c   5
# 6     a   7
# 7     b   8

# %%
dfgrades['prgrade']=dfgrades['grade'].astype("category")

# %%
dfgrades['prgrade']
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# 4    b
# 5    c
# 6    a
# 7    b
# Name: prgrade, dtype: category
# Categories (3, object): [a, b, c]

# %%
dfgrades['prgrade'].cat.categories=['verygood','good','verybad']

# %%
dfgrades['prgrade']
# Out:
# 0    verygood
# 1        good
# 2     verybad
# 3    verygood
# 4        good
# 5     verybad
# 6    verygood
# 7        good
# Name: prgrade, dtype: category
# Categories (3, object): [verygood, good, verybad]

# %%
dfgrades['prgrade']=dfgrades['prgrade'].cat.set_categories(["verybad","bad","good","verygood","medium","verymedium","badder","excellent"])

# %%
dfgrades['prgrade']
# Out:
# 0    verygood
# 1        good
# 2     verybad
# 3    verygood
# 4        good
# 5     verybad
# 6    verygood
# 7        good
# Name: prgrade, dtype: category
# Categories (8, object): [verybad, bad, good, verygood, medium, verymedium, badder, excellent]

# %%
rng=pd.date_range('20130101',periods=100,freq='S')

# %%
rng
# Out:
# DatetimeIndex(['2013-01-01 00:00:00', '2013-01-01 00:00:01',
#                '2013-01-01 00:00:02', '2013-01-01 00:00:03',
#                '2013-01-01 00:00:04', '2013-01-01 00:00:05',
#                '2013-01-01 00:00:06', '2013-01-01 00:00:07',
#                '2013-01-01 00:00:08', '2013-01-01 00:00:09',
#                '2013-01-01 00:00:10', '2013-01-01 00:00:11',
#                '2013-01-01 00:00:12', '2013-01-01 00:00:13',
#                '2013-01-01 00:00:14', '2013-01-01 00:00:15',
#                '2013-01-01 00:00:16', '2013-01-01 00:00:17',
#                '2013-01-01 00:00:18', '2013-01-01 00:00:19',
#                '2013-01-01 00:00:20', '2013-01-01 00:00:21',
#                '2013-01-01 00:00:22', '2013-01-01 00:00:23',
#                '2013-01-01 00:00:24', '2013-01-01 00:00:25',
#                '2013-01-01 00:00:26', '2013-01-01 00:00:27',
#                '2013-01-01 00:00:28', '2013-01-01 00:00:29',
# ...

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts=pd.Series(np.random.randint(0,500,len(rng)),index=rng)

# %%
ts
# Out:
# 2012-03-06    237
# 2012-03-07    246
# 2012-03-08    178
# 2012-03-09    369
# 2012-03-10    164
# Freq: D, dtype: int64

# %%
ts.resample('5Min').sum()
# Out:
# 2012-03-06 00:00:00    237
# 2012-03-06 00:05:00      0
# 2012-03-06 00:10:00      0
# 2012-03-06 00:15:00      0
# 2012-03-06 00:20:00      0
# 2012-03-06 00:25:00      0
# 2012-03-06 00:30:00      0
# 2012-03-06 00:35:00      0
# 2012-03-06 00:40:00      0
# 2012-03-06 00:45:00      0
# 2012-03-06 00:50:00      0
# 2012-03-06 00:55:00      0
# 2012-03-06 01:00:00      0
# 2012-03-06 01:05:00      0
# 2012-03-06 01:10:00      0
# 2012-03-06 01:15:00      0
# 2012-03-06 01:20:00      0
# 2012-03-06 01:25:00      0
# 2012-03-06 01:30:00      0
# 2012-03-06 01:35:00      0
# 2012-03-06 01:40:00      0
# 2012-03-06 01:45:00      0
# 2012-03-06 01:50:00      0
# 2012-03-06 01:55:00      0
# 2012-03-06 02:00:00      0
# 2012-03-06 02:05:00      0
# 2012-03-06 02:10:00      0
# 2012-03-06 02:15:00      0
# 2012-03-06 02:20:00      0
# 2012-03-06 02:25:00      0
#                       ...
# 2012-03-09 21:35:00      0
# 2012-03-09 21:40:00      0
# 2012-03-09 21:45:00      0
# ...
